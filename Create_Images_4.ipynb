# %%
import pandas as pd

df = pd.read_csv('images.csv')

df
# Out:
#                                      image  sender_id     label   kids
# 0     4285fab0-751a-4b74-8e9b-43af05deee22        124  Not sure  False
# 1     ea7b6656-3f84-4eb3-9099-23e623fc1018        148   T-Shirt  False
# 2     00627a3f-0477-401c-95eb-92642cbe078d         94  Not sure  False
# 3     ea2ffd4d-9b25-4ca8-9dc2-bd27f1cc59fa         43   T-Shirt  False
# 4     3b86d877-2b9e-4c8b-a6a2-1d87513309d0        189     Shoes  False
# ...                                    ...        ...       ...    ...
# 5398  dfd4079d-967b-4b3e-8574-fbac11b58103        204    Shorts  False
# 5399  befa14be-8140-4faf-8061-1039947e329d        204      Body   True
# 5400  5379356a-40ee-4890-b416-2336a7d84061        310    Shorts  False
# 5401  65507fb8-3456-4c15-b53e-d1b03bf71a59        204     Shoes  False
# 5402  32b99302-cec7-4dec-adfa-3d4029674209        204     Skirt  False
#
# [5403 rows x 4 columns]

# %%
df.label.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df.drop(['sender_id', 'kids'], axis=1, inplace=True)
df
# Out:
#                                      image     label
# 0     4285fab0-751a-4b74-8e9b-43af05deee22  Not sure
# 1     ea7b6656-3f84-4eb3-9099-23e623fc1018   T-Shirt
# 2     00627a3f-0477-401c-95eb-92642cbe078d  Not sure
# 3     ea2ffd4d-9b25-4ca8-9dc2-bd27f1cc59fa   T-Shirt
# 4     3b86d877-2b9e-4c8b-a6a2-1d87513309d0     Shoes
# ...                                    ...       ...
# 5398  dfd4079d-967b-4b3e-8574-fbac11b58103    Shorts
# 5399  befa14be-8140-4faf-8061-1039947e329d      Body
# 5400  5379356a-40ee-4890-b416-2336a7d84061    Shorts
# 5401  65507fb8-3456-4c15-b53e-d1b03bf71a59     Shoes
# 5402  32b99302-cec7-4dec-adfa-3d4029674209     Skirt
#
# [5403 rows x 2 columns]

# %%
df = df.set_index('image')
df
# Out:
#                                          label
# image
# 4285fab0-751a-4b74-8e9b-43af05deee22  Not sure
# ea7b6656-3f84-4eb3-9099-23e623fc1018   T-Shirt
# 00627a3f-0477-401c-95eb-92642cbe078d  Not sure
# ea2ffd4d-9b25-4ca8-9dc2-bd27f1cc59fa   T-Shirt
# 3b86d877-2b9e-4c8b-a6a2-1d87513309d0     Shoes
# ...                                        ...
# dfd4079d-967b-4b3e-8574-fbac11b58103    Shorts
# befa14be-8140-4faf-8061-1039947e329d      Body
# 5379356a-40ee-4890-b416-2336a7d84061    Shorts
# 65507fb8-3456-4c15-b53e-d1b03bf71a59     Shoes
# 32b99302-cec7-4dec-adfa-3d4029674209     Skirt
#
# [5403 rows x 1 columns]

# %%
splits = list(df.groupby('label'))

# %%
splits
# Out:
# [('Blazer',
#                                          label
#   image
#   396cdf47-f336-491c-919c-ae80cf1d02ba  Blazer
#   5008492c-339e-454c-b741-a676d22f1f5c  Blazer
#   0d9f1bf9-0008-4247-b22b-832ab1c62a70  Blazer
#   67242183-82be-491d-84cb-cd0ae9d00e19  Blazer
#   1fd19366-a938-4eb3-83c9-4bc474f495be  Blazer
#   ...                                      ...
#   ad19b17f-66d9-4f5b-8a90-9539f0311806  Blazer
#   cb24db34-d06c-4671-89a7-7f5e5eee7cdc  Blazer
#   64937043-1a83-4440-a5b3-c05f35bbe4fe  Blazer
#   4cd9a0b0-4953-47fb-b8d0-4eb9b3616b29  Blazer
#   7fe3f9b7-ccee-4d88-a165-389762f3d77a  Blazer
#
#   [109 rows x 1 columns]),
#  ('Blouse',
#                                          label
#   image
#   4ef0dece-adfc-4036-ad34-922d607d4bd5  Blouse
#   28455ee9-ca04-4efc-bb1f-73b56e6d2bd7  Blouse
#   c5b80186-15fa-4b9a-9ca4-88005b0db7bf  Blouse
#   0527af7c-3a7c-4c87-9e1c-bee2d9db0e98  Blouse
#   3163669a-a958-45d2-af43-b1fd70d21727  Blouse
# ...

# %%
bodies = splits[2][1]
not_sure = splits[7][1] 
other = splits[8][1] 
skip = splits[15][1]
tops = splits[18][1]

# %%
bodies
# Out:
#                                      label
# image
# 13aa07bd-cf38-4309-8dc2-daddffe43922  Body
# f4106e52-0286-4971-975c-8ba4c060ba71  Body
# 6ecfac41-dd0f-44ab-8c8a-3b7cc45924ea  Body
# d61893a4-ce8b-4e29-8928-727482d051cf  Body
# db41cac1-fba6-4b5d-abb5-e21f310cf84f  Body
# ...                                    ...
# 10304539-6db2-40bc-84a1-2316980ec4c9  Body
# 605e00c9-ebee-4dc9-8a42-eb88f631802e  Body
# 2b248c7e-802b-4403-b7f0-47201116ab49  Body
# 76edc0a1-409d-4d52-b826-0ce57ca16ccc  Body
# befa14be-8140-4faf-8061-1039947e329d  Body
#
# [69 rows x 1 columns]

# %%
for index in bodies.index:
    df.drop(index=index, inplace=True)

# %%
df.label.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
not_sure
# Out:
#                                          label
# image
# 4285fab0-751a-4b74-8e9b-43af05deee22  Not sure
# 00627a3f-0477-401c-95eb-92642cbe078d  Not sure
# c327ee2e-ec85-4e50-8f8b-c0953fd0f394  Not sure
# ede278ac-9b59-4d21-b456-ec35d9cc0300  Not sure
# d7c86d5d-0d38-4b69-8bc9-853784feca22  Not sure
# ...                                        ...
# a85dc6d0-6427-4ca0-83ef-5f393c5a12a2  Not sure
# 35549eed-e356-46f3-b412-36829beb2980  Not sure
# 95d9e258-ef5b-4cfc-852a-c1f8308cf31f  Not sure
# 65b69c94-7b60-4fba-8bff-52b50da9eb40  Not sure
# e2609b4b-77c9-4c36-8417-246afde001ca  Not sure
#
# [228 rows x 1 columns]

# %%
for index in not_sure.index:
    df.drop(index=index, inplace=True)

# %%
df.label.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
other
# Out:
#                                       label
# image
# 8659edca-30a6-4cd2-b2f0-8c9358f2a785  Other
# 71c85a46-6bf9-4929-a141-386d07bbe139  Other
# 9e56c5f9-9aa9-44f8-9976-653bcf4369cf  Other
# d8a2cddf-3308-457e-b0fe-c3230dc708d0  Other
# 49e8dc64-a109-494f-8ad8-656d074f359d  Other
# ...                                     ...
# 61327eff-6595-4d0e-8e02-84b93f60efae  Other
# 70839ad8-08a0-455d-98e4-746cefbb1091  Other
# cd9a9b0b-1d68-4e8c-bcca-3c6bc89b5d9e  Other
# 4471dd90-d9b2-4014-a001-1fe2dd006973  Other
# 6e69b257-4eaf-4785-95a9-f984ee195f20  Other
#
# [67 rows x 1 columns]

# %%
for index in other.index:
    df.drop(index=index, inplace=True)

# %%
df.label.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
skip
# Out:
#                                      label
# image
# 7e72662d-d284-4e75-800e-051cf95f4750  Skip
# f99fbb9c-6f57-49f6-a994-5506eb654c16  Skip
# d028580f-9a98-4fb5-a6c9-5dc362ad3f09  Skip
# 1d0129a1-f29a-4a3f-b103-f651176183eb  Skip
# 784d67d4-b95e-4abb-baf7-8024f18dc3c8  Skip
# 8ce65001-4242-4297-a7e7-69336e7087fb  Skip
# 597893dc-e9d6-4e1c-a060-b39569ad10a4  Skip
# a13897f4-75a7-491b-a813-4cb7472358a7  Skip
# 229c99a7-2bed-4013-ac54-fbf668a3f7b0  Skip
# c60e486d-10ed-4f64-abab-5bb698c736dd  Skip
# b739894c-5385-4b5d-a06f-26d57780161f  Skip
# 040d73b7-21b5-4cf2-84fc-e1a80231b202  Skip

# %%
for index in skip.index:
    df.drop(index=index, inplace=True)

# %%
df.label.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
tops
# Out:
#                                      label
# image
# 04b42565-23ce-47d9-8f11-e3f1fb0d5051   Top
# 6ba8aeb1-a812-4bd7-a0b3-d898aebe3400   Top
# fc739085-2b1b-4176-b255-eebf690c486a   Top
# 9b76f08a-3224-4767-8ee4-04a527777477   Top
# 6b1355ff-cc52-4e2a-a870-e91e75b926fe   Top
# 5d8bacce-65eb-4bff-9f89-3d023d881d37   Top
# 1a6601f1-4ad2-43c9-b1b6-d46e09995c7a   Top
# 6d3a3735-2676-4bdc-86d0-292d27a4ab81   Top
# 639e07c5-afc2-4ea0-ab13-5a77a25bf88f   Top
# 5593f86b-0cda-415c-8d93-5af040bfb6df   Top
# 1e53d9cf-bacd-4675-8e7c-5563ce2f743f   Top
# b9c867a9-6036-4936-bee4-1704de612352   Top
# 1f6b14a6-abcc-40ce-ae7f-6293177b15ac   Top
# 4e8edac8-e81c-4e2d-b0aa-462837a42c55   Top
# ab6cf197-7901-4bef-b6e3-2f1df054838d   Top
# a7a8fafc-8f77-4117-807a-f4a2f09741aa   Top
# be8d0e0c-6d9e-43fc-a528-fab862e0f6ff   Top
# 8523dd6f-c10f-432f-a6fd-39239a89de54   Top
# 455a4889-5b1d-41a3-a16b-d540aff1f2c6   Top
# 6bbcfcef-9b5d-4ba7-abb5-ed1881479959   Top
# fcd8821f-80ff-4b8a-8f87-8be36ae7288d   Top
# ...

# %%
for index in tops.index:
    df.drop(index=index, inplace=True)

# %%
df.label.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df.to_csv('images_4.csv')

# %%
check = pd.read_csv('images_4.csv')
check
# Out:
#                                      image    label
# 0     ea7b6656-3f84-4eb3-9099-23e623fc1018  T-Shirt
# 1     ea2ffd4d-9b25-4ca8-9dc2-bd27f1cc59fa  T-Shirt
# 2     3b86d877-2b9e-4c8b-a6a2-1d87513309d0    Shoes
# 3     5d3a1404-697f-479f-9090-c1ecd0413d27   Shorts
# 4     b0c03127-9dfb-4573-8934-1958396937bf    Shirt
# ...                                    ...      ...
# 4979  3855ea22-5e7f-411f-b1fa-6db27a676c06    Shoes
# 4980  dfd4079d-967b-4b3e-8574-fbac11b58103   Shorts
# 4981  5379356a-40ee-4890-b416-2336a7d84061   Shorts
# 4982  65507fb8-3456-4c15-b53e-d1b03bf71a59    Shoes
# 4983  32b99302-cec7-4dec-adfa-3d4029674209    Skirt
#
# [4984 rows x 2 columns]
